# %%
# %matplotlib inline
import matplotlib as mpl
mpl.style.use('/Users/nik/Dropbox/Repos/Notebooks/thesisrc.py')
mpl.rcParams['figure.figsize'] = 8,6
import os
import igor
from igor.binarywave import Waves
import itertools

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
cd /Users/nik/"Google Drive"/InXX_gold_aluminum_Jan2016
# Out:
# /Users/nik/Google Drive/InXX_gold_aluminum_Jan2016

# %% [markdown]
# ## Low Temperature Measurements
#
# For everything below here T ~ 7mK, at least at the mixing chamber. The sample temperature not well known, yet.

# %%
# SIN wire
# AuS3_LR_4770 (chip name - which corner - sole's RT resistance value)

Vac = 10e-6
condquant = 3.75e-5
amplification = 1e-6
multiplier = amplification/Vac/condquant

w = Waves('dat23g1x.ibw', y_multiplier = multiplier)

fig, ax = plt.subplots(1,1)
ax.plot(w.x/1000.0, w.y)
ax.set_xlabel('$V_{BG}\ (V)$')
ax.set_ylabel(r'$G\ (e^2/h)$')

# %%
# SIN wire
# AuS3_LR_4770 (chip name - which corner - sole's RT resistance value)

Vac = 10e-6
condquant = 3.75e-5
amplification = 1e-6
multiplier = amplification/Vac/condquant

w = Waves('dat24g2d1x.ibw', y_multiplier = multiplier)
u = Waves('dat25g2d1x.ibw', y_multiplier = multiplier)

fig, ax = plt.subplots(1,2, figsize = (14,6))
extent = [a/1000.0 for a in w.extent]
ax[0].imshow(w.y, extent = extent, aspect = 'auto',
             vmin = 0.0, vmax = 20.0, 
             interpolation='nearest')
ax[0].set_ylabel('$V_{bias}\ (mV)$')
ax[0].set_xlabel('$V_{BG}\ (V)$')
extent = [a/1000.0 for a in u.extent]
im = ax[1].imshow(u.y, extent = extent, aspect = 'auto',
                  vmin = 0.0, vmax = 20.0, 
                  interpolation='nearest')
ax[1].set_xlabel('$V_{BG}\ (V)$')

cb = plt.colorbar(im)
cb.set_label(r'$e^2/h$')

# %%
# SIN wire AuS3_UR_240

Vac = 10e-6
condquant = 3.75e-5
amplification = 1e-7
multiplier = amplification/Vac/condquant

w = Waves('dat29g1x.ibw', y_multiplier = multiplier)

fig, ax = plt.subplots(1,1)
ax.plot(w.x/1000.0, w.y)
ax.set_ylim(10, 11)
ax.set_xlabel('$V_{BG}\ (V)$')
ax.set_ylabel(r'$G\ (e^2/h)$')

# %%
# SIN wire AuS3_UR_240

Vac = 10e-6
condquant = 3.75e-5
amplification = 1e-7
multiplier = amplification/Vac/condquant

w = Waves('dat30g2d1x.ibw', y_multiplier = multiplier)

fig, ax = plt.subplots(1,1)
extent = [a/1000.0 for a in w.extent]
im = ax.imshow(w.y, extent = extent, aspect = 'auto',
#                 vmin = 0.0, vmax = 2.0, 
                  interpolation='nearest')
ax.set_ylabel('$V_{bias}\ (mV)$')
ax.set_xlabel('$V_{BG}\ (V)$')

cb = plt.colorbar(im)
cb.set_label(r'$e^2/h$')

# %%
# SIN wire AuS3_UR_240

Vac = 10e-6
condquant = 3.75e-5
amplification = 1e-7
multiplier = amplification/Vac/condquant

w = Waves('dat31g1x.ibw', y_multiplier = multiplier)

fig, ax = plt.subplots(1,1)
ax.plot(w.x/1000.0, w.y)
ax.set_ylim(10, 11)
ax.set_xlabel('$V_{bias}\ (mV)$')
ax.set_ylabel(r'$G\ (e^2/h)$')

# %%
# SIS wire Au3S_UR_349

Vac = 10e-6
condquant = 3.75e-5
amplification = 1e-7
multiplier = amplification/Vac/condquant

w = Waves('dat32g1x.ibw', y_multiplier = multiplier)
u = Waves('dat33g2d1x.ibw', y_multiplier = multiplier)

fig, ax = plt.subplots(1,2, figsize = (14,6))
ax[0].plot(w.x/1000.0, w.y)
ax[0].set_ylim(9, 11)
ax[0].set_xlabel('$V_{BG}\ (V)$')
ax[0].set_ylabel('$G\ (e^2/h)$')

extent = [a/1000.0 for a in u.extent]
im = ax[1].imshow(u.y, extent = extent, aspect = 'auto',
#                 vmin = 0.0, vmax = 2.0, 
                  interpolation='nearest')
ax[1].set_xlabel('$V_{BG}\ (V)$')
ax[1].set_ylabel('$V_{bias}\ (mV)$')

cb = plt.colorbar(im)
cb.set_label('$e^2/h$')
fig.tight_layout()

# %%
# SIS wire Au3S_UL_489

Vac = 10e-6
condquant = 3.75e-5
amplification = 1e-7
multiplier = amplification/Vac/condquant

w = Waves('dat34g1x.ibw', y_multiplier = multiplier)
ww = Waves('dat35g1x.ibw', y_multiplier = multiplier)
u = Waves('dat36g2d1x.ibw', y_multiplier = multiplier)

fig, ax = plt.subplots(1,2, figsize = (14,6))
ax[0].plot(w.x/1000.0, w.y)
ax[0].plot(ww.x/1000.0, ww.y)
# ax[0].set_ylim(9, 11)
ax[0].set_xlabel('$V_{BG}\ (V)$')
ax[0].set_ylabel('$G\ (e^2/h)$')

extent = [a/1000.0 for a in u.extent]
im = ax[1].imshow(u.y, extent = extent, aspect = 'auto',
#                 vmin = 0.0, vmax = 2.0, 
                  interpolation='nearest', cmap = plt.cm.viridis)
ax[1].set_xlabel('$V_{BG}\ (V)$')
ax[1].set_ylabel('$V_{bias}\ (mV)$')

cb = plt.colorbar(im)
cb.set_label('$e^2/h$')
fig.tight_layout()

# %%
# SIS wire Au3S_LL_2132

Vac = 10e-6
condquant = 3.75e-5
amplification = 1e-7
multiplier = amplification/Vac/condquant

w = Waves('dat37g1x.ibw', y_multiplier = multiplier)
ww = Waves('dat38g1x.ibw', y_multiplier = multiplier)
u = Waves('dat39g2d1x.ibw', y_multiplier = multiplier)

fig, ax = plt.subplots(1,2, figsize = (14,6))
ax[0].plot(w.x/1000.0, w.y)
ax[0].plot(ww.x/1000.0, ww.y)
# ax[0].set_ylim(9, 11)
ax[0].set_xlabel('$V_{BG}\ (V)$')
ax[0].set_ylabel('$G\ (e^2/h)$')

extent = [a/1000.0 for a in u.extent]
im = ax[1].imshow(u.y, extent = extent, aspect = 'auto',
#                 vmin = 0.0, vmax = 2.0, 
                  interpolation='nearest', cmap = plt.cm.viridis)
ax[1].set_xlabel('$V_{BG}\ (V)$')
ax[1].set_ylabel('$V_{bias}\ (mV)$')

cb = plt.colorbar(im)
cb.set_label('$e^2/h$')
fig.tight_layout()

# %%
# SIS wire Au3S_LL_1185

Vac = 10e-6
condquant = 3.75e-5
amplification = 1e-7
multiplier = amplification/Vac/condquant

w = Waves('dat40g1x.ibw', y_multiplier = multiplier)
u = Waves('dat41g2d1x.ibw', y_multiplier = multiplier)

fig, ax = plt.subplots(1,2, figsize = (14,6))
ax[0].plot(w.x/1000.0, w.y)
# ax[0].set_ylim(9, 11)
ax[0].set_xlabel('$V_{BG}\ (V)$')
ax[0].set_ylabel('$G\ (e^2/h)$')

extent = [a/1000.0 for a in u.extent]
im = ax[1].imshow(u.y, extent = extent, aspect = 'auto',
#                 vmin = 0.0, vmax = 2.0, 
                  interpolation='nearest', cmap = plt.cm.viridis)
ax[1].set_xlabel('$V_{BG}\ (V)$')
ax[1].set_ylabel('$V_{bias}\ (mV)$')

cb = plt.colorbar(im)
cb.set_label('$e^2/h$')
fig.tight_layout()

# %% [markdown]
# ### Switching to current biased measurement
#
# Iac = 1nA

# %%
# SIS wire Au3S_LL_2132

Iac = 1e-9
amplification = 1e-3
multiplier = amplification/Iac

w0 = Waves('dat55g1x.ibw', y_multiplier = multiplier)
w1 = Waves('dat56g1x.ibw', y_multiplier = multiplier)
w2 = Waves('dat57g1x.ibw', y_multiplier = multiplier)
u = Waves('dat58g2d1x.ibw', y_multiplier = multiplier)

fig, ax = plt.subplots(1,2, figsize = (14,6))
ax[0].plot(w0.x/1000.0, w0.y)
ax[0].plot(w1.x/1000.0, w1.y)
ax[0].plot(w2.x/1000.0, w2.y)
# ax[0].set_ylim(9, 11)
ax[0].set_xlabel('$V_{bias}\ (mV)$')
ax[0].set_ylabel('$R\ (k\Omega)$')

extent = [a/1000.0 for a in u.extent]
im = ax[1].imshow(u.y, extent = extent, aspect = 'auto',
                  vmin = 5500.0, vmax = 7000.0, 
                  interpolation='nearest', cmap = plt.cm.viridis)
ax[1].set_xlabel('$V_{BG}\ (V)$')
ax[1].set_ylabel('$V_{bias}\ (mV)$')

cb = plt.colorbar(im)
cb.set_label('$k\Omega$')
fig.tight_layout()
